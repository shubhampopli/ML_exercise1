# %% [markdown]
# #                                      APRIORI ALGORITHM
# Shubam popli 209

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset1 = pd.read_excel ('APPLICATION_CPY.xlsx')

# %%
dataset1
# Out:
#            ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0     5008804           M            Y               Y             0
# 1     5008805           M            Y               Y             0
# 2     5008806           M            Y               Y             0
# 3     5008808           F            N               Y             0
# 4     5008809           F            N               Y             0
# ...       ...         ...          ...             ...           ...
# 3994  5023442           F            N               Y             0
# 3995  5023443           F            N               Y             0
# 3996  5023444           F            N               Y             0
# 3997  5023445           F            N               Y             0
# 3998  5023447           F            N               Y             0
#
#       AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dataset1.drop(['ID','CNT_CHILDREN','AMT_INCOME_TOTAL','DAYS_BIRTH','DAYS_EMPLOYED','FLAG_MOBIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_EMAIL','CNT_FAM_MEMBERS'],axis=1,inplace=True)

# %%
dataset1
# Out:
#      CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY      NAME_INCOME_TYPE  \
# 0              M            Y               Y               Working
# 1              M            Y               Y               Working
# 2              M            Y               Y               Working
# 3              F            N               Y  Commercial associate
# 4              F            N               Y  Commercial associate
# ...          ...          ...             ...                   ...
# 3994           F            N               Y               Working
# 3995           F            N               Y               Working
# 3996           F            N               Y               Working
# 3997           F            N               Y               Working
# 3998           F            N               Y  Commercial associate
#
#                 NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# ...

# %%
dataset1.dropna(inplace=True)

# %%
dataset1.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY      NAME_INCOME_TYPE  \
# 2           M            Y               Y               Working
# 3           F            N               Y  Commercial associate
# 4           F            N               Y  Commercial associate
# 5           F            N               Y  Commercial associate
# 6           F            N               Y  Commercial associate
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 2  Secondary / secondary special               Married  House / apartment
# 3  Secondary / secondary special  Single / not married  House / apartment
# 4  Secondary / secondary special  Single / not married  House / apartment
# 5  Secondary / secondary special  Single / not married  House / apartment
# 6  Secondary / secondary special  Single / not married  House / apartment
#
#   OCCUPATION_TYPE
# 2  Security staff
# 3     Sales staff
# 4     Sales staff
# 5     Sales staff
# 6     Sales staff

# %%
dataset1.describe()
# Out:
#        CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY NAME_INCOME_TYPE  \
# count         2745         2745            2745             2745
# unique           2            2               2                4
# top              F            N               Y          Working
# freq          1688         1462            1923             1698
#
#                   NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# count                            2745               2745               2745
# unique                              4                  5                  6
# top     Secondary / secondary special            Married  House / apartment
# freq                             1836               1953               2423
#
#        OCCUPATION_TYPE
# count             2745
# unique              17
# top           Laborers
# freq               650

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2745 entries, 2 to 3998
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CODE_GENDER          2745 non-null   object
#  1   FLAG_OWN_CAR         2745 non-null   object
#  2   FLAG_OWN_REALTY      2745 non-null   object
#  3   NAME_INCOME_TYPE     2745 non-null   object
#  4   NAME_EDUCATION_TYPE  2745 non-null   object
#  5   NAME_FAMILY_STATUS   2745 non-null   object
#  6   NAME_HOUSING_TYPE    2745 non-null   object
#  7   OCCUPATION_TYPE      2745 non-null   object
# dtypes: object(8)
# memory usage: 193.0+ KB

# %%
transactions = []
for i in range(0, len(dataset1)):
    transactions.append([str(dataset1.values[i,j]) for j in range(0, 8)])

# %%
from apyori import apriori
rules = apriori(transactions, min_support = 2, min_confidence = 0.7, min_length = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87d8f918a6cf> in <module>
#       1 from apyori import apriori
# ----> 2 rules = apriori(transactions, min_support = 2, min_confidence = 0.7, min_length = 2)
#
# NameError: name 'transactions' is not defined

# %%
results = list(rules)

# %%
results

# %%
lift = []
association = []
for i in range (0, len(results)):
    lift.append(results[:len(results)][i][2][0][3])
    association.append(list(results[:len(results)][i][0]))

# %%
rank = pd.DataFrame([association, lift]).transpose()
rank.columns = ['Association', 'Lift']

# %%
# Show top 10 higher lift scores
rank.sort_values('Lift', ascending=False).head(10)
